# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mydata=pd.read_csv("E:\PARTHO\Programming\Python\sample.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9044\617042549.py:1: SyntaxWarning: invalid escape sequence '\P'
#   mydata=pd.read_csv("E:\PARTHO\Programming\Python\sample.csv")

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              25 non-null     int64
#  1   Major             25 non-null     object
#  2   Degree Type       25 non-null     object
#  3   Early Career Pay  25 non-null     object
#  4   Mid-Career Pay    25 non-null     object
#  5   % High Meaning    25 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.3+ KB

# %%
mydata.head()
# Out:
#    Rank                                             Major Degree Type  \
# 0     1                             Petroleum Engineering   Bachelors
# 1     2      Operations Research & Industrial Engineering   Bachelors
# 2     3  Electrical Engineering & Computer Science (EECS)   Bachelors
# 3     4                                Interaction Design   Bachelors
# 4     5                                  Building Science   Bachelors
#
#   Early Career Pay Mid-Career Pay % High Meaning
# 0         $98,100       $212,100             60%
# 1        $101,200       $202,600             21%
# 2        $128,500       $192,300             45%
# 3         $77,400       $178,800             55%
# 4         $71,100       $172,400             46%

# %%
mydata.T
# Out:
#                                      0   \
# Rank                                  1
# Major             Petroleum Engineering
# Degree Type                   Bachelors
# Early Career Pay               $98,100
# Mid-Career Pay                $212,100
# % High Meaning                      60%
#
#                                                             1   \
# Rank                                                         2
# Major             Operations Research & Industrial Engineering
# Degree Type                                          Bachelors
# Early Career Pay                                     $101,200
# Mid-Career Pay                                       $202,600
# % High Meaning                                             21%
#
#                                                                 2   \
# Rank                                                             3
# Major             Electrical Engineering & Computer Science (EECS)
# ...

# %%
mydata.Major
# Out:
# 0                                Petroleum Engineering
# 1         Operations Research & Industrial Engineering
# 2     Electrical Engineering & Computer Science (EECS)
# 3                                   Interaction Design
# 4                                     Building Science
# 5                     Applied Economics and Management
# 6                                Actuarial Mathematics
# 7                        Optical Science & Engineering
# 8                               Quantitative Economics
# 9                                  Operations Research
# 10                                 Systems Engineering
# 11                      Information & Computer Science
# 12                                   Public Accounting
# 13                                   Cognitive Science
# 14                          Aeronautics & Astronautics
# 15                                   Aerospace Studies
# 16                                            Pharmacy
# ...

# %%
mydata['Degree Type']
# Out:
# 0     Bachelors
# 1     Bachelors
# 2     Bachelors
# 3     Bachelors
# 4     Bachelors
# 5     Bachelors
# 6     Bachelors
# 7     Bachelors
# 8     Bachelors
# 9     Bachelors
# 10    Bachelors
# 11    Bachelors
# 12    Bachelors
# 13    Bachelors
# 14    Bachelors
# 15    Bachelors
# 16    Bachelors
# 17    Bachelors
# 18    Bachelors
# 19    Bachelors
# 20    Bachelors
# 21    Bachelors
# 22    Bachelors
# 23    Bachelors
# 24    Bachelors
# Name: Degree Type, dtype: object

# %%
mydata2=mydata

# %%
mydata.loc[mydata['% High Meaning']=='-']
# Out:
#     Rank                             Major Degree Type Early Career Pay  \
# 15    16                 Aerospace Studies   Bachelors         $64,500
# 21    21  Marine Transportation Management   Bachelors         $78,500
# 23    24    Corporate Accounting & Finance   Bachelors         $79,100
#
#    Mid-Career Pay % High Meaning
# 15      $158,400               -
# 21      $156,100               -
# 23      $154,000               -

# %%
mydata2['% High Meaning']=pd.to_numeric(mydata['% High Meaning'].str.rstrip('%'),errors='coerce')
mydata.dtypes
# Out:
# Rank                  int64
# Major                object
# Degree Type          object
# Early Career Pay     object
# Mid-Career Pay       object
# % High Meaning      float64
# dtype: object

# %%
mydata2['Early Career Pay']=pd.to_numeric(mydata['Early Career Pay'].str.lstrip('$').str.replace(',',''))/100
mydata2['Mid-Career Pay']=pd.to_numeric(mydata['Mid-Career Pay'].str.lstrip('$').str.replace(',',''))/100
mydata.dtypes
# Out:
# Rank                  int64
# Major                object
# Degree Type          object
# Early Career Pay    float64
# Mid-Career Pay      float64
# % High Meaning      float64
# dtype: object

# %%
mydata2.columns=['Rank','Major','Degree Type','Early Career Pay in Dollars(x100)','Mid-Career Pay in Dollars(x100)','High Meaning(%)']

# %%
ecp=np.array(mydata2['Early Career Pay in Dollars(x100)'])
mcp=np.array(mydata2['Mid-Career Pay in Dollars(x100)'])
incr=mcp-ecp
incr_col=pd.DataFrame(incr,columns=['Increment in Dollars(x100)'])

# %%
mydata2=pd.concat([mydata,incr_col],axis=1)
mydata2.head()
# Out:
#    Rank                                             Major Degree Type  \
# 0     1                             Petroleum Engineering   Bachelors
# 1     2      Operations Research & Industrial Engineering   Bachelors
# 2     3  Electrical Engineering & Computer Science (EECS)   Bachelors
# 3     4                                Interaction Design   Bachelors
# 4     5                                  Building Science   Bachelors
#
#    Early Career Pay in Dollars(x100)  Mid-Career Pay in Dollars(x100)  \
# 0                              981.0                           2121.0
# 1                             1012.0                           2026.0
# 2                             1285.0                           1923.0
# 3                              774.0                           1788.0
# 4                              711.0                           1724.0
#
#    High Meaning(%)  Increment in Dollars(x100)
# 0             60.0                      1140.0
# ...

# %%
mydata2.loc[mydata2['Increment in Dollars(x100)']>700]
# Out:
#     Rank                                         Major Degree Type  \
# 0      1                         Petroleum Engineering   Bachelors
# 1      2  Operations Research & Industrial Engineering   Bachelors
# 3      4                            Interaction Design   Bachelors
# 4      5                              Building Science   Bachelors
# 5      6              Applied Economics and Management   Bachelors
# 6      7                         Actuarial Mathematics   Bachelors
# 7      8                 Optical Science & Engineering   Bachelors
# 8      9                        Quantitative Economics   Bachelors
# 10    11                           Systems Engineering   Bachelors
# 11    12                Information & Computer Science   Bachelors
# 12    13                             Public Accounting   Bachelors
# 13    14                             Cognitive Science   Bachelors
# 14    15                    Aeronautics & Astronautics   Bachelors
# ...

# %%
# !print(mydata['High Meaning(%)'].mean(skipna=True))
# Out:
# Unable to initialize device PRN

# %%
# !print(mydata['Early Career Pay'].min())
# !print(mydata['Mid-Career Pay'].max())
# !print(mydata['Mid-Career Pay'].min())
# !print(mydata['% High Meaning'].max())
# !print(mydata['% High Meaning'].min())
# Out:
# Unable to initialize device PRN
# Unable to initialize device PRN
# Unable to initialize device PRN
# Unable to initialize device PRN
# Unable to initialize device PRN

# %%
mydata2.describe()
# Out:
#             Rank  Early Career Pay in Dollars(x100)  \
# count  25.000000                          25.000000
# mean   12.960000                         829.600000
# std     7.311407                         137.714378
# min     1.000000                         645.000000
# 25%     7.000000                         732.000000
# 50%    13.000000                         791.000000
# 75%    19.000000                         898.000000
# max    25.000000                        1285.000000
#
#        Mid-Career Pay in Dollars(x100)  High Meaning(%)  \
# count                        25.000000        22.000000
# mean                       1666.680000        49.545455
# std                         150.051858        13.623255
# min                        1538.000000        21.000000
# 25%                        1577.000000        43.250000
# 50%                        1622.000000        47.000000
# 75%                        1675.000000        56.750000
# ...

# %%
mydata2.loc[mydata2['Mid-Career Pay in Dollars(x100)']==2121.0 ]
# Out:
#    Rank                  Major Degree Type  Early Career Pay in Dollars(x100)  \
# 0     1  Petroleum Engineering   Bachelors                              981.0
#
#    Mid-Career Pay in Dollars(x100)  High Meaning(%)  \
# 0                           2121.0             60.0
#
#    Increment in Dollars(x100)
# 0                      1140.0

# %%
mydata2.loc[mydata2['Early Career Pay in Dollars(x100)']==1285]
# Out:
#    Rank                                             Major Degree Type  \
# 2     3  Electrical Engineering & Computer Science (EECS)   Bachelors
#
#    Early Career Pay in Dollars(x100)  Mid-Career Pay in Dollars(x100)  \
# 2                             1285.0                           1923.0
#
#    High Meaning(%)  Increment in Dollars(x100)
# 2             45.0                       638.0

# %%
mydata2.loc[mydata2['High Meaning(%)']==80]
# Out:
#     Rank     Major Degree Type  Early Career Pay in Dollars(x100)  \
# 16    17  Pharmacy   Bachelors                              715.0
#
#     Mid-Career Pay in Dollars(x100)  High Meaning(%)  \
# 16                           1580.0             80.0
#
#     Increment in Dollars(x100)
# 16                       865.0

# %%
mydata2.loc[mydata2['High Meaning(%)']==21]
# Out:
#    Rank                                         Major Degree Type  \
# 1     2  Operations Research & Industrial Engineering   Bachelors
#
#    Early Career Pay in Dollars(x100)  Mid-Career Pay in Dollars(x100)  \
# 1                             1012.0                           2026.0
#
#    High Meaning(%)  Increment in Dollars(x100)
# 1             21.0                      1014.0

# %%
mydata2.loc[mydata2['High Meaning(%)']<40]
# Out:
#     Rank                                         Major Degree Type  \
# 1      2  Operations Research & Industrial Engineering   Bachelors
# 17    18                          Managerial Economics   Bachelors
# 18    19                               Foreign Affairs   Bachelors
# 19    20                             Political Economy   Bachelors
#
#     Early Career Pay in Dollars(x100)  Mid-Career Pay in Dollars(x100)  \
# 1                              1012.0                           2026.0
# 17                              782.0                           1578.0
# 18                              652.0                           1577.0
# 19                              758.0                           1567.0
#
#     High Meaning(%)  Increment in Dollars(x100)
# 1              21.0                      1014.0
# 17             38.0                       796.0
# 18             32.0                       925.0
# 19             30.0                       809.0

# %%
mydata2['High Meaning(%)'].value_counts()
# Out:
# High Meaning(%)
# 60.0    2
# 47.0    2
# 43.0    2
# 46.0    2
# 21.0    1
# 55.0    1
# 45.0    1
# 48.0    1
# 73.0    1
# 56.0    1
# 57.0    1
# 65.0    1
# 80.0    1
# 38.0    1
# 32.0    1
# 30.0    1
# 54.0    1
# 44.0    1
# Name: count, dtype: int64

# %%
floatcategory=mydata2.select_dtypes(include='float').columns

# %%
for col in floatcategory:
    print(f'Frequncy of {col}:')
    print(mydata2[col].value_counts().head())
# Out:
# Frequncy of Early Career Pay in Dollars(x100):
# Early Career Pay in Dollars(x100)
# 715.0     2
# 981.0     1
# 1285.0    1
# 1012.0    1
# 711.0     1
# Name: count, dtype: int64
# Frequncy of Mid-Career Pay in Dollars(x100):
# Mid-Career Pay in Dollars(x100)
# 1561.0    2
# 2121.0    1
# 1923.0    1
# 2026.0    1
# 1724.0    1
# Name: count, dtype: int64
# Frequncy of High Meaning(%):
# High Meaning(%)
# 60.0    2
# 47.0    2
# 43.0    2
# 46.0    2
# 21.0    1
# Name: count, dtype: int64
# Frequncy of Increment in Dollars(x100):
# Increment in Dollars(x100)
# 1014.0    2
# 1140.0    1
# 638.0     1
# 1013.0    1
# 881.0     1
# Name: count, dtype: int64

# %%
# !mydata.at[15,'High Meaning(%)']='Data Not Collected'
# !mydata.at[21,'High Meaning(%)']='Data Not Collected'
# !mydata.at[23,'High Meaning(%)']='Data Not Collected'
# Out:
# 'mydata.at[15' is not recognized as an internal or external command,
# operable program or batch file.
# 'mydata.at[21' is not recognized as an internal or external command,
# operable program or batch file.
# 'mydata.at[23' is not recognized as an internal or external command,
# operable program or batch file.

# %%
mydata.iloc[:3,:2]
# Out:
#    Rank                                             Major
# 0     1                             Petroleum Engineering
# 1     2      Operations Research & Industrial Engineering
# 2     3  Electrical Engineering & Computer Science (EECS)

# %%
mydata.loc[:3,:'Early Career Pay in Dollars(x100)']
# Out:
#    Rank                                             Major Degree Type  \
# 0     1                             Petroleum Engineering   Bachelors
# 1     2      Operations Research & Industrial Engineering   Bachelors
# 2     3  Electrical Engineering & Computer Science (EECS)   Bachelors
# 3     4                                Interaction Design   Bachelors
#
#    Early Career Pay in Dollars(x100)
# 0                              981.0
# 1                             1012.0
# 2                             1285.0
# 3                              774.0

# %%
mydata.dtypes
# Out:
# Rank                                   int64
# Major                                 object
# Degree Type                           object
# Early Career Pay in Dollars(x100)    float64
# Mid-Career Pay in Dollars(x100)      float64
# High Meaning(%)                      float64
# dtype: object

# %%
mydata=pd.read_csv("E:\PARTHO\Programming\Python\sample.csv")
mydata.columns=['Rank','Major','Degree Type','Early Career Pay in Dollars(x100)','Mid-Career Pay in Dollars(x100)','High Meaning(%)']
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9044\2639305947.py:1: SyntaxWarning: invalid escape sequence '\P'
#   mydata=pd.read_csv("E:\PARTHO\Programming\Python\sample.csv")

# %%
mydata['High Meaning(%)']=pd.to_numeric(mydata['High Meaning(%)'].str.rstrip('%'),errors='coerce')
mydata['Early Career Pay in Dollars(x100)']=pd.to_numeric(mydata['Early Career Pay in Dollars(x100)'].str.lstrip('$').str.replace(',',''))/100
mydata['Mid-Career Pay in Dollars(x100)']=pd.to_numeric(mydata['Mid-Career Pay in Dollars(x100)'].str.lstrip('$').str.replace(',',''))/100
mydata.dtypes
# Out:
# Rank                                   int64
# Major                                 object
# Degree Type                           object
# Early Career Pay in Dollars(x100)    float64
# Mid-Career Pay in Dollars(x100)      float64
# High Meaning(%)                      float64
# dtype: object

# %%
plt.hist(mydata2['Early Career Pay in Dollars(x100)'],edgecolor='black')
plt.xlabel('Pay in Dollars(x100)')
plt.ylabel('Frequency')
plt.title('Early Career Pay');

# %%
plt.hist(mydata2['Mid-Career Pay in Dollars(x100)'],color='orange',edgecolor='black')
plt.xlabel('Pay in Dollars(x100)')
plt.ylabel('Frequency')
plt.title('Early Career Pay');

# %%
plt.hist(mydata2['High Meaning(%)'],color='red',edgecolor='black')
plt.xlabel('High Meaning(%)')
plt.ylabel('Frequency')
plt.title('Percentage of High Meaning');

# %%
plt.figure(figsize=(6,8))
plt.barh(mydata2['Major'],mydata2['Early Career Pay in Dollars(x100)'],edgecolor='black')
plt.xlabel('Payment in Dollars(x100)')
plt.ylabel('Major')
plt.title('Early Career Payment for different Major');

# %%
plt.figure(figsize=(6,8))
plt.barh(mydata2['Major'],mydata2['Mid-Career Pay in Dollars(x100)'],color='green',edgecolor='black')
plt.xlabel('Payment in Dollars(x100)')
plt.ylabel('Major')
plt.title('Mid-Career Payment for different Major');

# %%
plt.figure(figsize=(6,8))
plt.barh(mydata2['Major'],mydata2['High Meaning(%)'],color='blue',edgecolor='black')
plt.xlabel('High Meaning(%)')
plt.ylabel('Major')
plt.title('Percentage of High Meaning for different Major');

# %%
mydata.dtypes
# Out:
# Rank                                   int64
# Major                                 object
# Degree Type                           object
# Early Career Pay in Dollars(x100)    float64
# Mid-Career Pay in Dollars(x100)      float64
# High Meaning(%)                      float64
# dtype: object

# %%
numerical=['Early Career Pay in Dollars(x100)','Mid-Career Pay in Dollars(x100)','High Meaning(%)']
categorical=['Major','Degree Type']

# %%
fig, axs=plt.subplots(2,2,figsize=(10,10))
axs=axs.ravel()

for i,col in enumerate(numerical):
    axs[i].hist(mydata2[col],edgecolor='black',bins=10)
    axs[i].set_xlabel(f'{col}')
    axs[i].set_ylabel('Density')
    axs[i].set_title(f'Frequency of {col}')
    axs[i].tick_params(axis='x',rotation=65)
plt.tight_layout()

# %%
mydata.dtypes
# Out:
# Rank                                   int64
# Major                                 object
# Degree Type                           object
# Early Career Pay in Dollars(x100)    float64
# Mid-Career Pay in Dollars(x100)      float64
# High Meaning(%)                      float64
# dtype: object

# %%
mydata=pd.read_csv("E:\PARTHO\Programming\Python\sample.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9044\617042549.py:1: SyntaxWarning: invalid escape sequence '\P'
#   mydata=pd.read_csv("E:\PARTHO\Programming\Python\sample.csv")

# %%
mydata4=mydata

# %%
mydata4['% High Meaning']=mydata4['% High Meaning'].replace('-','Assumed to be more than 35%')

# %%
mydata4.loc[mydata4['% High Meaning']=='Assumed to be more than 35%']
# Out:
#     Rank                             Major Degree Type Early Career Pay  \
# 15    16                 Aerospace Studies   Bachelors         $64,500
# 21    21  Marine Transportation Management   Bachelors         $78,500
# 23    24    Corporate Accounting & Finance   Bachelors         $79,100
#
#    Mid-Career Pay               % High Meaning
# 15      $158,400   Assumed to be more than 35%
# 21      $156,100   Assumed to be more than 35%
# 23      $154,000   Assumed to be more than 35%

# %%
incr4=(mcp-ecp)*100
incr_col4=pd.DataFrame(incr4,columns=['Increment'])
mydata4=pd.concat([mydata4,incr_col4],axis=1)

# %%
mydata4['Increment']=mydata4['Increment'].apply(lambda x:f'${x}')

# %%
mydata4['Increment']=mydata4['Increment'].apply(lambda x:str(x)[:4]+','+str(x)[4:])

# %%
mydata4
# Out:
#     Rank                                             Major Degree Type  \
# 0      1                             Petroleum Engineering   Bachelors
# 1      2      Operations Research & Industrial Engineering   Bachelors
# 2      3  Electrical Engineering & Computer Science (EECS)   Bachelors
# 3      4                                Interaction Design   Bachelors
# 4      5                                  Building Science   Bachelors
# 5      6                  Applied Economics and Management   Bachelors
# 6      7                             Actuarial Mathematics   Bachelors
# 7      8                     Optical Science & Engineering   Bachelors
# 8      9                            Quantitative Economics   Bachelors
# 9     10                               Operations Research   Bachelors
# 10    11                               Systems Engineering   Bachelors
# 11    12                    Information & Computer Science   Bachelors
# ...
